# %%
# Import Dependencies
import pandas as pd
import numpy as np
import matplotlib
from matplotlib import style
style.use('fivethirtyeight')
import matplotlib.pyplot as plt
# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, inspect, func
import datetime as dt

# %%
# Upload csv

stock_data_csv = "C:/Users/Satinder Bains/Desktop/Stocks Vs Gold Allocation/Datasets/snp500.csv"
stock_data_csv

gold_data_csv = "C:/Users/Satinder Bains/Desktop/Stocks Vs Gold Allocation/Datasets/goldx.csv"
gold_data_csv

gold_extended = "C:/Users/Satinder Bains/Desktop/Stocks Vs Gold Allocation/Datasets/Gold-quandl.csv"
gold_extended
# Out:
# 'C:/Users/Satinder Bains/Desktop/Stocks Vs Gold Allocation/Datasets/Gold-quandl.csv'

# %%
# The correct encoding must be used to read the CSV in pandas
gold_df = pd.read_csv(gold_data_csv, encoding='utf-8')
gold_df.head()
# Out:
#            Date   Price    Open    High     Low
# 0  Aug 01, 2018  1216.6  1223.4  1223.4  1216.2
# 1  Jul 31, 2018  1223.7  1220.4  1228.1  1213.0
# 2  Jul 30, 2018  1221.3  1222.5  1223.9  1218.1
# 3  Jul 27, 2018  1222.2  1223.5  1226.8  1216.7
# 4  Jul 26, 2018  1225.3  1227.8  1227.8  1227.8

# %% [markdown]
# ### Cleaning Stock Data

# %%
# The correct encoding must be used to read the CSV in pandas
stocks_df = pd.read_csv(stock_data_csv, encoding='utf-8')
stocks_df.head()
# Out:
#          Date   Open   High    Low  Close  Adj Close   Volume
# 0  1950-01-03  16.66  16.66  16.66  16.66      16.66  1260000
# 1  1950-01-04  16.85  16.85  16.85  16.85      16.85  1890000
# 2  1950-01-05  16.93  16.93  16.93  16.93      16.93  2550000
# 3  1950-01-06  16.98  16.98  16.98  16.98      16.98  2010000
# 4  1950-01-09  17.08  17.08  17.08  17.08      17.08  2520000

# %%
# Check Datatypes
stocks_df.dtypes
# Out:
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# dtype: object

# %%
# Count Columns
stocks_df.count()
# Out:
# Date         17543
# Open         17543
# High         17543
# Low          17543
# Close        17543
# Adj Close    17543
# Volume       17543
# dtype: int64

# %%
# Delete extraneous column
del stocks_df['Volume']
del stocks_df['Adj Close']
stocks_df.head()
# Out:
#          Date   Open   High    Low  Close
# 0  1950-01-03  16.66  16.66  16.66  16.66
# 1  1950-01-04  16.85  16.85  16.85  16.85
# 2  1950-01-05  16.93  16.93  16.93  16.93
# 3  1950-01-06  16.98  16.98  16.98  16.98
# 4  1950-01-09  17.08  17.08  17.08  17.08

# %%
# Find the Date
# Loc and Iloc also allow for conditional statments to filter rows of data
# using Loc on the logic test above only returns rows where the result is True
only_billys = stocks_df.loc[stocks_df["Date"] == "1980-01-01", :]
print(only_billys)
# Out:
# Empty DataFrame
# Columns: [Date, Open, High, Low, Close]
# Index: []

# %%
#FormatDatesProperly
newFormat = pd.to_datetime(stocks_df['Date'])

# %%
dataformat = stocks_df.set_index('Date')
dataformat.head()
# Out:
#              Open   High    Low  Close
# Date
# 1950-01-03  16.66  16.66  16.66  16.66
# 1950-01-04  16.85  16.85  16.85  16.85
# 1950-01-05  16.93  16.93  16.93  16.93
# 1950-01-06  16.98  16.98  16.98  16.98
# 1950-01-09  17.08  17.08  17.08  17.08

# %%
# Delete extraneous column
del stocks_df['Date']
stocks_df.head()
# Out:
#     Open   High    Low  Close
# 0  16.66  16.66  16.66  16.66
# 1  16.85  16.85  16.85  16.85
# 2  16.93  16.93  16.93  16.93
# 3  16.98  16.98  16.98  16.98
# 4  17.08  17.08  17.08  17.08

# %%
#Concat datasets
stocks_df = pd.concat([stocks_df, newFormat], axis=1)
stocks_df.head()
# Out:
#     Open   High    Low  Close       Date
# 0  16.66  16.66  16.66  16.66 1950-01-03
# 1  16.85  16.85  16.85  16.85 1950-01-04
# 2  16.93  16.93  16.93  16.93 1950-01-05
# 3  16.98  16.98  16.98  16.98 1950-01-06
# 4  17.08  17.08  17.08  17.08 1950-01-09

# %%
dataformat = stocks_df.set_index('Date')
dataformat.head()
# Out:
#              Open   High    Low  Close
# Date
# 1950-01-03  16.66  16.66  16.66  16.66
# 1950-01-04  16.85  16.85  16.85  16.85
# 1950-01-05  16.93  16.93  16.93  16.93
# 1950-01-06  16.98  16.98  16.98  16.98
# 1950-01-09  17.08  17.08  17.08  17.08

# %% [markdown]
# # Gold Cleaning
#
# ## Part I

# %%
# The correct encoding must be used to read the CSV in pandas
gold_extend = pd.read_csv(gold_extended, encoding='utf-8')
gold_extend.head()
# Out:
#          Date  USD (AM)  USD (PM)  GBP (AM)  GBP (PM)  EURO (AM)  EURO (PM)
# 0  2017-10-24   1278.30   1276.45    970.36    970.48    1087.32    1085.62
# 1  2017-10-23   1275.25   1274.90    967.79    966.37    1085.62    1085.07
# 2  2017-10-20   1280.25   1281.20    974.27    973.20    1084.76    1086.97
# 3  2017-10-19   1283.40   1286.40    975.64    975.35    1087.42    1085.98
# 4  2017-10-18   1280.65   1280.20    972.53    973.08    1090.47    1088.55

# %%
#Reverse order so lowest dates show first
aux = gold_extend.iloc[::-1]
aux.head()
# Out:
#              Date  USD (AM)  USD (PM)  GBP (AM)  GBP (PM)  EURO (AM)  \
# 12590  1968-01-02     35.18       NaN    14.641       NaN        NaN
# 12589  1968-01-03     35.16       NaN    14.617       NaN        NaN
# 12588  1968-01-04     35.14       NaN    14.603       NaN        NaN
# 12587  1968-01-05     35.14       NaN    14.597       NaN        NaN
# 12586  1968-01-08     35.14       NaN    14.586       NaN        NaN
#
#        EURO (PM)
# 12590        NaN
# 12589        NaN
# 12588        NaN
# 12587        NaN
# 12586        NaN

# %%
aux.fillna
# Out:
# <bound method DataFrame.fillna of              Date  USD (AM)  USD (PM)  GBP (AM)  GBP (PM)  EURO (AM)  \
# 12590  1968-01-02     35.18       NaN    14.641       NaN        NaN
# 13     2017-10-05   1278.40   1274.50   969.280    970.28    1086.51
# 12     2017-10-06   1268.20   1261.80   970.430    967.93    1083.93
# 11     2017-10-09   1282.15   1278.75   976.230    972.23    1092.01
# 10     2017-10-10   1289.60   1291.40   977.770    978.88    1094.61
# 9      2017-10-11   1290.20   1289.25   978.620    976.35    1091.90
# 8      2017-10-12   1294.45   1290.25   977.960    981.75    1092.26
# 7      2017-10-13   1293.90   1299.60   972.880    975.74    1093.73
# 6      2017-10-16   1305.15   1303.30   981.080    981.25    1107.03
# 5      2017-10-17   1289.70   1284.75   973.470    975.38    1097.02
# 4      2017-10-18   1280.65   1280.20   972.530    973.08    1090.47
# 3      2017-10-19   1283.40   1286.40   975.640    975.35    1087.42
# 2      2017-10-20   1280.25   1281.20   974.270    973.20    1084.76
# 1      2017-10-23   1275.25   1274.90   967.790    966.37    1085.62
# 0      2017-10-24   1278.30   1276.45   970.360    970.48    1087.32
#
#        EURO (PM)
# 12590        NaN
# 12589        NaN
# 12588        NaN
# 12587        NaN
# 12586        NaN
# 12585        NaN
# 12584        NaN
# 12583        NaN
# 12582        NaN
# 12581        NaN
# 12580        NaN
# 12579        NaN
# 12578        NaN
# 12577        NaN
# 12576        NaN
# 12575        NaN
# 12574        NaN
# 12573        NaN
# 12572        NaN
# 12571        NaN
# 12570        NaN
# 12569        NaN
# 12568        NaN
# 12567        NaN
# 12566        NaN
# 12565        NaN
# 12564        NaN
# 12563        NaN
# 12562        NaN
# 12561        NaN
# ...          ...
# 29       1112.22
# 28       1114.61
# 27       1105.37
# 26       1096.65
# 25       1092.86
# 24       1092.71
# 23       1083.81
# 22       1081.55
# 21       1088.57
# 20       1103.09
# 19       1094.14
# 18       1088.02
# 17       1087.43
# 16       1084.81
# 15       1081.33
# 14       1084.13
# 13       1087.28
# 12       1078.59
# 11       1090.01
# 10       1094.07
# 9        1087.61
# 8        1090.52
# 7        1095.43
# 6        1104.16
# 5        1094.48
# 4        1088.55
# 3        1085.98
# 2        1086.97
# 1        1085.07
# 0        1085.62
#
# [12591 rows x 7 columns]>

# %%
#FormatDatesProperly
auDate = pd.to_datetime(aux['Date'])
auDate.head()
# Out:
# 12590   1968-01-02
# 12589   1968-01-03
# 12588   1968-01-04
# 12587   1968-01-05
# 12586   1968-01-08
# Name: Date, dtype: datetime64[ns]

# %%
#Delete Object "Date"
del aux['Date']

# %%
# Add Date Format to Dataframe
#if you want to specify the order of the column, you can use insert
#here, we are inserting at index 1 (so should be second col in dataframe)
#here is the simplist way to add the new column
auDate  = pd.concat([aux, auDate], axis=1)
auDate.head()
# Out:
#        USD (AM)  USD (PM)  GBP (AM)  GBP (PM)  EURO (AM)  EURO (PM)       Date
# 12590     35.18       NaN    14.641       NaN        NaN        NaN 1968-01-02
# 12589     35.16       NaN    14.617       NaN        NaN        NaN 1968-01-03
# 12588     35.14       NaN    14.603       NaN        NaN        NaN 1968-01-04
# 12587     35.14       NaN    14.597       NaN        NaN        NaN 1968-01-05
# 12586     35.14       NaN    14.586       NaN        NaN        NaN 1968-01-08

# %%
auDate.dtypes
# Out:
# USD (AM)            float64
# USD (PM)            float64
# GBP (AM)            float64
# GBP (PM)            float64
# EURO (AM)           float64
# EURO (PM)           float64
# Date         datetime64[ns]
# dtype: object

# %%
indexAU = auDate.set_index('Date')
indexAU.head()
# Out:
#             USD (AM)  USD (PM)  GBP (AM)  GBP (PM)  EURO (AM)  EURO (PM)
# Date
# 1968-01-02     35.18       NaN    14.641       NaN        NaN        NaN
# 1968-01-03     35.16       NaN    14.617       NaN        NaN        NaN
# 1968-01-04     35.14       NaN    14.603       NaN        NaN        NaN
# 1968-01-05     35.14       NaN    14.597       NaN        NaN        NaN
# 1968-01-08     35.14       NaN    14.586       NaN        NaN        NaN

# %% [markdown]
# ## Part II

# %%
gold_df.head()
# Out:
#            Date   Price    Open    High     Low
# 0  Aug 01, 2018  1216.6  1223.4  1223.4  1216.2
# 1  Jul 31, 2018  1223.7  1220.4  1228.1  1213.0
# 2  Jul 30, 2018  1221.3  1222.5  1223.9  1218.1
# 3  Jul 27, 2018  1222.2  1223.5  1226.8  1216.7
# 4  Jul 26, 2018  1225.3  1227.8  1227.8  1227.8

# %%
# Check Datatype
gold_df.dtypes
# Out:
# Date      object
# Price    float64
# Open     float64
# High     float64
# Low      float64
# dtype: object

# %%
#FormatDatesProperly
newFormatGold = pd.to_datetime(gold_df['Date'])
newFormatGold.head()
# Out:
# 0   2018-08-01
# 1   2018-07-31
# 2   2018-07-30
# 3   2018-07-27
# 4   2018-07-26
# Name: Date, dtype: datetime64[ns]

# %%
newFormatGold.dtype
# Out:
# dtype('<M8[ns]')

# %%
del gold_df['Date']

# %%
# Add Date Format to Dataframe
#if you want to specify the order of the column, you can use insert
#here, we are inserting at index 1 (so should be second col in dataframe)
#here is the simplist way to add the new column
au_ya  = pd.concat([gold_df, newFormatGold], axis=1)
au_ya.head()
# Out:
#     Price    Open    High     Low       Date
# 0  1216.6  1223.4  1223.4  1216.2 2018-08-01
# 1  1223.7  1220.4  1228.1  1213.0 2018-07-31
# 2  1221.3  1222.5  1223.9  1218.1 2018-07-30
# 3  1222.2  1223.5  1226.8  1216.7 2018-07-27
# 4  1225.3  1227.8  1227.8  1227.8 2018-07-26

# %%
#Reverse order so lowest dates show first
au_ya = au_ya.iloc[::-1]
au_ya.head()
# Out:
#       Price    Open   High     Low       Date
# 9770  515.5  517.00  517.0  513.00 1979-12-27
# 9769  517.8  516.00  517.8  510.40 1979-12-28
# 9768  533.6  527.88  534.5  527.88 1979-12-31
# 9767  575.5  562.50  577.0  558.00 1980-01-02
# 9766  625.0  627.00  640.0  603.00 1980-01-03

# %%
au_ya.dtypes
# Out:
# Price           float64
# Open            float64
# High            float64
# Low             float64
# Date     datetime64[ns]
# dtype: object

# %%
gold_final = au_ya.set_index('Date')
gold_final.head()
# Out:
#             Price    Open   High     Low
# Date
# 1979-12-27  515.5  517.00  517.0  513.00
# 1979-12-28  517.8  516.00  517.8  510.40
# 1979-12-31  533.6  527.88  534.5  527.88
# 1980-01-02  575.5  562.50  577.0  558.00
# 1980-01-03  625.0  627.00  640.0  603.00

# %% [markdown]
# # MERGEDASET

# %%
#Merge Gold Dataset
mergeAU = pd.merge(indexAU, gold_final, on="Date", how="outer")
mergeAU.head()
# Out:
#             USD (AM)  USD (PM)  GBP (AM)  GBP (PM)  EURO (AM)  EURO (PM)  \
# Date
# 1968-01-02     35.18       NaN    14.641       NaN        NaN        NaN
# 1968-01-03     35.16       NaN    14.617       NaN        NaN        NaN
# 1968-01-04     35.14       NaN    14.603       NaN        NaN        NaN
# 1968-01-05     35.14       NaN    14.597       NaN        NaN        NaN
# 1968-01-08     35.14       NaN    14.586       NaN        NaN        NaN
#
#             Price  Open  High  Low
# Date
# 1968-01-02    NaN   NaN   NaN  NaN
# 1968-01-03    NaN   NaN   NaN  NaN
# 1968-01-04    NaN   NaN   NaN  NaN
# 1968-01-05    NaN   NaN   NaN  NaN
# 1968-01-08    NaN   NaN   NaN  NaN

# %%
#Merge datasets
merge_table = pd.merge(mergeAU, dataformat, on="Date", how='outer')
merge_table.head()
# Out:
#             USD (AM)  USD (PM)  GBP (AM)  GBP (PM)  EURO (AM)  EURO (PM)  \
# Date
# 1968-01-02     35.18       NaN    14.641       NaN        NaN        NaN
# 1968-01-03     35.16       NaN    14.617       NaN        NaN        NaN
# 1968-01-04     35.14       NaN    14.603       NaN        NaN        NaN
# 1968-01-05     35.14       NaN    14.597       NaN        NaN        NaN
# 1968-01-08     35.14       NaN    14.586       NaN        NaN        NaN
#
#             Price  Open_x  High_x  Low_x     Open_y     High_y      Low_y  \
# Date
# 1968-01-02    NaN     NaN     NaN    NaN  96.470001  97.330002  95.309998
# 1968-01-03    NaN     NaN     NaN    NaN  96.110001  96.949997  95.040001
# 1968-01-04    NaN     NaN     NaN    NaN  95.669998  96.230003  94.309998
# 1968-01-05    NaN     NaN     NaN    NaN  95.360001  96.660004  94.970001
# 1968-01-08    NaN     NaN     NaN    NaN  95.940002  97.400002  95.540001
#
#                 Close
# Date
# 1968-01-02  96.110001
# 1968-01-03  95.669998
# 1968-01-04  95.360001
# 1968-01-05  95.940002
# 1968-01-08  96.620003

# %%
# Using .rename(columns={}) in order to rename columns
renamed_df = merge_table.rename(columns={"High_y":"SP.High", "Low_y":"SP.Low", "Price":"AU.Price",
                                        "Open_x":"AU.Open", "High_x":"AU.High", "Low_x":"AU.Low", 'Close':'SP.Price',
                                        'Open_y':'SP.Open', 'USD (AM)':'Gold.Price', 'USD (PM)':'Gold.Close'})
renamed_df.head()
# Out:
#             Gold.Price  Gold.Close  GBP (AM)  GBP (PM)  EURO (AM)  EURO (PM)  \
# Date
# 1968-01-02       35.18         NaN    14.641       NaN        NaN        NaN
# 1968-01-03       35.16         NaN    14.617       NaN        NaN        NaN
# 1968-01-04       35.14         NaN    14.603       NaN        NaN        NaN
# 1968-01-05       35.14         NaN    14.597       NaN        NaN        NaN
# 1968-01-08       35.14         NaN    14.586       NaN        NaN        NaN
#
#             AU.Price  AU.Open  AU.High  AU.Low    SP.Open    SP.High  \
# Date
# 1968-01-02       NaN      NaN      NaN     NaN  96.470001  97.330002
# 1968-01-03       NaN      NaN      NaN     NaN  96.110001  96.949997
# 1968-01-04       NaN      NaN      NaN     NaN  95.669998  96.230003
# 1968-01-05       NaN      NaN      NaN     NaN  95.360001  96.660004
# 1968-01-08       NaN      NaN      NaN     NaN  95.940002  97.400002
#
#                SP.Low   SP.Price
# Date
# 1968-01-02  95.309998  96.110001
# 1968-01-03  95.040001  95.669998
# 1968-01-04  94.309998  95.360001
# 1968-01-05  94.970001  95.940002
# 1968-01-08  95.540001  96.620003

# %%
#Fill price of Gold.Price with Au.Price updated to end of 79
test1 = renamed_df['AU.Price'].fillna(renamed_df['Gold.Price'])
test1.head()
# Out:
# Date
# 1968-01-02    35.18
# 1968-01-03    35.16
# 1968-01-04    35.14
# 1968-01-05    35.14
# 1968-01-08    35.14
# Name: AU.Price, dtype: float64

# %%
#Fill price of Gold.Price with Au.Price updated to end of 79
test2 = renamed_df['Gold.Price'].fillna(renamed_df['AU.Price'])
test2.head()
# Out:
# Date
# 1968-01-02    35.18
# 1968-01-03    35.16
# 1968-01-04    35.14
# 1968-01-05    35.14
# 1968-01-08    35.14
# Name: Gold.Price, dtype: float64

# %%
renamed_df['AU.Price'] = renamed_df['AU.Price'].fillna(value=renamed_df['Gold.Price'])
renamed_df.head(3050)
# Out:
#             Gold.Price  Gold.Close  GBP (AM)  GBP (PM)  EURO (AM)  EURO (PM)  \
# Date
# 1968-01-02       35.18         NaN    14.641       NaN        NaN        NaN
# 1968-01-03       35.16         NaN    14.617       NaN        NaN        NaN
# 1968-01-04       35.14         NaN    14.603       NaN        NaN        NaN
# 1968-01-05       35.14         NaN    14.597       NaN        NaN        NaN
# 1968-01-08       35.14         NaN    14.586       NaN        NaN        NaN
# 1968-01-09       35.14         NaN    14.576       NaN        NaN        NaN
# 1968-01-10       35.15         NaN    14.576       NaN        NaN        NaN
# 1968-01-11       35.17         NaN    14.596       NaN        NaN        NaN
# 1968-01-12       35.18         NaN    14.607       NaN        NaN        NaN
# 1968-01-15       35.18         NaN    14.597       NaN        NaN        NaN
# 1968-01-16       35.19         NaN    14.596       NaN        NaN        NaN
# 1968-01-17       35.20         NaN    14.613       NaN        NaN        NaN
# 1968-01-18       35.20         NaN    14.608       NaN        NaN        NaN
# 1968-01-19       35.19         NaN    14.610       NaN        NaN        NaN
# 1968-01-22       35.19         NaN    14.606       NaN        NaN        NaN
# 1968-01-23       35.19         NaN    14.607       NaN        NaN        NaN
# 1968-01-24       35.20         NaN    14.603       NaN        NaN        NaN
# 1968-01-25       35.20         NaN    14.604       NaN        NaN        NaN
# 1968-01-26       35.20         NaN    14.604       NaN        NaN        NaN
# 1968-01-29       35.19         NaN    14.600       NaN        NaN        NaN
# 1968-01-30       35.19         NaN    14.593       NaN        NaN        NaN
# 1968-01-31       35.20         NaN    14.592       NaN        NaN        NaN
# 1968-02-01       35.20         NaN    14.594       NaN        NaN        NaN
# 1968-02-02       35.20         NaN    14.595       NaN        NaN        NaN
# 1968-02-05       35.19         NaN    14.594       NaN        NaN        NaN
# 1968-02-06       35.19         NaN    14.597       NaN        NaN        NaN
# 1968-02-07       35.20         NaN    14.593       NaN        NaN        NaN
# 1968-02-08       35.19         NaN    14.600       NaN        NaN        NaN
# 1968-02-09       35.20         NaN    14.602       NaN        NaN        NaN
# 1968-02-12       35.19         NaN    14.598       NaN        NaN        NaN
# ...                ...         ...       ...       ...        ...        ...
# 1979-12-10      431.35      431.15   198.504   198.778        NaN        NaN
# 1979-12-11      442.75      445.50   202.511   203.750        NaN        NaN
# 1979-12-12      449.75      446.25   204.293   203.053        NaN        NaN
# 1979-12-13      458.75      458.80   208.428   208.073        NaN        NaN
# 1979-12-14      459.50      456.80   209.054   208.176        NaN        NaN
# 1979-12-17      460.60      469.50   209.221   213.409        NaN        NaN
# 1979-12-18      473.50      477.75   215.286   217.238        NaN        NaN
# 1979-12-19      494.00      488.50   224.240   221.622        NaN        NaN
# 1979-12-20      477.25      471.50   216.735   214.172        NaN        NaN
# 1979-12-21      474.90      473.10   216.208   215.241        NaN        NaN
# 1979-12-24      485.90         NaN   220.463       NaN        NaN        NaN
# 1979-12-27      508.75         NaN   228.806       NaN        NaN        NaN
# 1979-12-28      515.00      512.00   230.528   229.391        NaN        NaN
# 1979-12-31      524.00         NaN   235.189       NaN        NaN        NaN
# 1980-01-02      559.00      559.50   251.123   250.841        NaN        NaN
# 1980-01-03      632.00      634.00   281.577   282.468        NaN        NaN
# 1980-01-04      596.00      588.00   266.285   262.770        NaN        NaN
# 1980-01-07      634.00      633.50   281.653   280.062        NaN        NaN
# 1980-01-08      615.75      610.00   273.060   270.270        NaN        NaN
# 1980-01-09      599.25      607.20   265.237   267.725        NaN        NaN
# 1980-01-10      608.25      602.85   268.484   266.783        NaN        NaN
# 1980-01-11      610.00      623.00   269.732   275.969        NaN        NaN
# 1980-01-14      647.75      660.00   285.982   290.685        NaN        NaN
# 1980-01-15      682.00      684.00   297.882   299.213        NaN        NaN
# 1980-01-16      765.00      760.00   335.674   333.480        NaN        NaN
# 1980-01-17      728.25      750.00   322.591   329.815        NaN        NaN
# 1980-01-18      825.50      835.00   361.823   365.347        NaN        NaN
# 1980-01-21      843.00      850.00   367.753   371.066        NaN        NaN
# 1980-01-22      763.00      737.50   334.546   323.820        NaN        NaN
# 1980-01-23      650.00      695.00   286.029   305.025        NaN        NaN
#
#             AU.Price  AU.Open  AU.High  AU.Low     SP.Open     SP.High  \
# Date
# 1968-01-02     35.18      NaN      NaN     NaN   96.470001   97.330002
# 1980-01-03  103.260002  105.220001
# 1980-01-04  105.089996  106.519997
# 1980-01-07  105.800003  106.809998
# 1980-01-08  106.290001  108.949997
# 1980-01-09  108.410004  109.050003
# 1980-01-10  108.470001  109.889999
# 1980-01-11  108.889999  109.919998
# 1980-01-14  109.339996  110.379997
# 1980-01-15  109.449997  111.139999
# 1980-01-16  110.379997  111.050003
# 1980-01-17  109.809998  110.699997
# 1980-01-18  109.879997  111.070000
# 1980-01-21  110.660004  112.099998
# 1980-01-22  110.919998  111.510002
# 1980-01-23  110.930000  113.440002
#
# [3050 rows x 14 columns]

# %%
final = renamed_df.reset_index()
final.head()
# Out:
#         Date  Gold.Price  Gold.Close  GBP (AM)  GBP (PM)  EURO (AM)  \
# 0 1968-01-02       35.18         NaN    14.641       NaN        NaN
# 1 1968-01-03       35.16         NaN    14.617       NaN        NaN
# 2 1968-01-04       35.14         NaN    14.603       NaN        NaN
# 3 1968-01-05       35.14         NaN    14.597       NaN        NaN
# 4 1968-01-08       35.14         NaN    14.586       NaN        NaN
#
#    EURO (PM)  AU.Price  AU.Open  AU.High  AU.Low    SP.Open    SP.High  \
# 0        NaN     35.18      NaN      NaN     NaN  96.470001  97.330002
# 1        NaN     35.16      NaN      NaN     NaN  96.110001  96.949997
# 2        NaN     35.14      NaN      NaN     NaN  95.669998  96.230003
# 3        NaN     35.14      NaN      NaN     NaN  95.360001  96.660004
# 4        NaN     35.14      NaN      NaN     NaN  95.940002  97.400002
#
#       SP.Low   SP.Price
# 0  95.309998  96.110001
# 1  95.040001  95.669998
# 2  94.309998  95.360001
# 3  94.970001  95.940002
# 4  95.540001  96.620003

# %%
final.count()
# Out:
# Date          17860
# Gold.Price    12590
# Gold.Close    12456
# GBP (AM)      12580
# GBP (PM)      12445
# EURO (AM)      4754
# EURO (PM)      4719
# AU.Price      12988
# AU.Open        9771
# AU.High        9771
# AU.Low         9771
# SP.Open       17543
# SP.High       17543
# SP.Low        17543
# SP.Price      17543
# dtype: int64

# %%
#final['Date1'] = final['Date'].dt.strftime('%m/%d/%Y')
#print (final)

final['DATE'] = final['Date'].apply(lambda x: x.strftime('%Y-%m-%d'))
final.head()
# Out:
#         Date  Gold.Price  Gold.Close  GBP (AM)  GBP (PM)  EURO (AM)  \
# 0 1968-01-02       35.18         NaN    14.641       NaN        NaN
# 1 1968-01-03       35.16         NaN    14.617       NaN        NaN
# 2 1968-01-04       35.14         NaN    14.603       NaN        NaN
# 3 1968-01-05       35.14         NaN    14.597       NaN        NaN
# 4 1968-01-08       35.14         NaN    14.586       NaN        NaN
#
#    EURO (PM)  AU.Price  AU.Open  AU.High  AU.Low    SP.Open    SP.High  \
# 0        NaN     35.18      NaN      NaN     NaN  96.470001  97.330002
# 1        NaN     35.16      NaN      NaN     NaN  96.110001  96.949997
# 2        NaN     35.14      NaN      NaN     NaN  95.669998  96.230003
# 3        NaN     35.14      NaN      NaN     NaN  95.360001  96.660004
# 4        NaN     35.14      NaN      NaN     NaN  95.940002  97.400002
#
#       SP.Low   SP.Price        DATE
# 0  95.309998  96.110001  1968-01-02
# 1  95.040001  95.669998  1968-01-03
# 2  94.309998  95.360001  1968-01-04
# 3  94.970001  95.940002  1968-01-05
# 4  95.540001  96.620003  1968-01-08

# %%
#final['Date1'] = final['Date'].dt.strftime('%m/%d/%Y')
#final.head()

# %%
date_format = pd.to_datetime(final['DATE'])
date_format.head()
# Out:
# 0   1968-01-02
# 1   1968-01-03
# 2   1968-01-04
# 3   1968-01-05
# 4   1968-01-08
# Name: DATE, dtype: datetime64[ns]

# %%
del final['DATE']
#del final['Date']

# %%
final_format  = pd.concat([final, date_format], axis=1)
final_format.head()
# Out:
#         Date  Gold.Price  Gold.Close  GBP (AM)  GBP (PM)  EURO (AM)  \
# 0 1968-01-02       35.18         NaN    14.641       NaN        NaN
# 1 1968-01-03       35.16         NaN    14.617       NaN        NaN
# 2 1968-01-04       35.14         NaN    14.603       NaN        NaN
# 3 1968-01-05       35.14         NaN    14.597       NaN        NaN
# 4 1968-01-08       35.14         NaN    14.586       NaN        NaN
#
#    EURO (PM)  AU.Price  AU.Open  AU.High  AU.Low    SP.Open    SP.High  \
# 0        NaN     35.18      NaN      NaN     NaN  96.470001  97.330002
# 1        NaN     35.16      NaN      NaN     NaN  96.110001  96.949997
# 2        NaN     35.14      NaN      NaN     NaN  95.669998  96.230003
# 3        NaN     35.14      NaN      NaN     NaN  95.360001  96.660004
# 4        NaN     35.14      NaN      NaN     NaN  95.940002  97.400002
#
#       SP.Low   SP.Price       DATE
# 0  95.309998  96.110001 1968-01-02
# 1  95.040001  95.669998 1968-01-03
# 2  94.309998  95.360001 1968-01-04
# 3  94.970001  95.940002 1968-01-05
# 4  95.540001  96.620003 1968-01-08

# %%
final_format.dtypes
# Out:
# Date          datetime64[ns]
# Gold.Price           float64
# Gold.Close           float64
# GBP (AM)             float64
# GBP (PM)             float64
# EURO (AM)            float64
# EURO (PM)            float64
# AU.Price             float64
# AU.Open              float64
# AU.High              float64
# AU.Low               float64
# SP.Open              float64
# SP.High              float64
# SP.Low               float64
# SP.Price             float64
# DATE          datetime64[ns]
# dtype: object

# %%
final_format['Year'] = final_format['DATE'].dt.year

final_format['Month'] = final_format['DATE'].dt.month

final_format['Day'] = final_format['DATE'].dt.day

# %%
# Remove two columns name is 'C' and 'D' 
final_format = final_format.drop(['DATE'], axis = 1)

# %%
practiceloc = final_format.set_index('Date')
practiceloc.head()
# Out:
#             Gold.Price  Gold.Close  GBP (AM)  GBP (PM)  EURO (AM)  EURO (PM)  \
# Date
# 1968-01-02       35.18         NaN    14.641       NaN        NaN        NaN
# 1968-01-03       35.16         NaN    14.617       NaN        NaN        NaN
# 1968-01-04       35.14         NaN    14.603       NaN        NaN        NaN
# 1968-01-05       35.14         NaN    14.597       NaN        NaN        NaN
# 1968-01-08       35.14         NaN    14.586       NaN        NaN        NaN
#
#             AU.Price  AU.Open  AU.High  AU.Low    SP.Open    SP.High  \
# Date
# 1968-01-02     35.18      NaN      NaN     NaN  96.470001  97.330002
# 1968-01-03     35.16      NaN      NaN     NaN  96.110001  96.949997
# 1968-01-04     35.14      NaN      NaN     NaN  95.669998  96.230003
# 1968-01-05     35.14      NaN      NaN     NaN  95.360001  96.660004
# 1968-01-08     35.14      NaN      NaN     NaN  95.940002  97.400002
#
#                SP.Low   SP.Price  Year  Month  Day
# Date
# 1968-01-02  95.309998  96.110001  1968      1    2
# 1968-01-03  95.040001  95.669998  1968      1    3
# 1968-01-04  94.309998  95.360001  1968      1    4
# 1968-01-05  94.970001  95.940002  1968      1    5
# 1968-01-08  95.540001  96.620003  1968      1    8

# %%
#delete extraneous columns
droptop = practiceloc.drop(['Gold.Price', 'Gold.Close'], axis = 1)
droptop.head()
# Out:
#             GBP (AM)  GBP (PM)  EURO (AM)  EURO (PM)  AU.Price  AU.Open  \
# Date
# 1968-01-02    14.641       NaN        NaN        NaN     35.18      NaN
# 1968-01-03    14.617       NaN        NaN        NaN     35.16      NaN
# 1968-01-04    14.603       NaN        NaN        NaN     35.14      NaN
# 1968-01-05    14.597       NaN        NaN        NaN     35.14      NaN
# 1968-01-08    14.586       NaN        NaN        NaN     35.14      NaN
#
#             AU.High  AU.Low    SP.Open    SP.High     SP.Low   SP.Price  Year  \
# Date
# 1968-01-02      NaN     NaN  96.470001  97.330002  95.309998  96.110001  1968
# 1968-01-03      NaN     NaN  96.110001  96.949997  95.040001  95.669998  1968
# 1968-01-04      NaN     NaN  95.669998  96.230003  94.309998  95.360001  1968
# 1968-01-05      NaN     NaN  95.360001  96.660004  94.970001  95.940002  1968
# 1968-01-08      NaN     NaN  95.940002  97.400002  95.540001  96.620003  1968
#
#             Month  Day
# Date
# 1968-01-02      1    2
# 1968-01-03      1    3
# 1968-01-04      1    4
# 1968-01-05      1    5
# 1968-01-08      1    8

# %%
droptop = droptop[[
    'SP.Price','SP.Open','SP.Low','SP.High',
    'AU.Price','AU.Open','AU.Low','AU.High',
    'GBP (AM)','GBP (PM)','EURO (AM)','EURO (PM)',
    'Month','Day','Year']]
droptop.head()
# Out:
#              SP.Price    SP.Open     SP.Low    SP.High  AU.Price  AU.Open  \
# Date
# 1968-01-02  96.110001  96.470001  95.309998  97.330002     35.18      NaN
# 1968-01-03  95.669998  96.110001  95.040001  96.949997     35.16      NaN
# 1968-01-04  95.360001  95.669998  94.309998  96.230003     35.14      NaN
# 1968-01-05  95.940002  95.360001  94.970001  96.660004     35.14      NaN
# 1968-01-08  96.620003  95.940002  95.540001  97.400002     35.14      NaN
#
#             AU.Low  AU.High  GBP (AM)  GBP (PM)  EURO (AM)  EURO (PM)  Month  \
# Date
# 1968-01-02     NaN      NaN    14.641       NaN        NaN        NaN      1
# 1968-01-03     NaN      NaN    14.617       NaN        NaN        NaN      1
# 1968-01-04     NaN      NaN    14.603       NaN        NaN        NaN      1
# 1968-01-05     NaN      NaN    14.597       NaN        NaN        NaN      1
# 1968-01-08     NaN      NaN    14.586       NaN        NaN        NaN      1
#
#             Day  Year
# Date
# 1968-01-02    2  1968
# 1968-01-03    3  1968
# 1968-01-04    4  1968
# 1968-01-05    5  1968
# 1968-01-08    8  1968

# %%
UncleSam = droptop[[
    'SP.Price','SP.Open','SP.Low','SP.High',
    'AU.Price','AU.Open','AU.Low','AU.High',
    'Month','Day','Year']]
UncleSam.head()
# Out:
#              SP.Price    SP.Open     SP.Low    SP.High  AU.Price  AU.Open  \
# Date
# 1968-01-02  96.110001  96.470001  95.309998  97.330002     35.18      NaN
# 1968-01-03  95.669998  96.110001  95.040001  96.949997     35.16      NaN
# 1968-01-04  95.360001  95.669998  94.309998  96.230003     35.14      NaN
# 1968-01-05  95.940002  95.360001  94.970001  96.660004     35.14      NaN
# 1968-01-08  96.620003  95.940002  95.540001  97.400002     35.14      NaN
#
#             AU.Low  AU.High  Month  Day  Year
# Date
# 1968-01-02     NaN      NaN      1    2  1968
# 1968-01-03     NaN      NaN      1    3  1968
# 1968-01-04     NaN      NaN      1    4  1968
# 1968-01-05     NaN      NaN      1    5  1968
# 1968-01-08     NaN      NaN      1    8  1968

# %%
# Grab the data contained within the "Berry" row and the "Phone Number" column
#simran = practiceloc.loc["1987-08-17", "AU.Price"]
#print("Using Loc: " + simran)

# %%
#Store time interval periods in dictionary
#one_yr = []
#two_yr = []
#five_yr = []
#ten_yr = []

#years = final_format["Year"]
#months = final_format['Month']
#days = final_format['Day']
#gold_price = final_format['AU.Price']
#sp_price = final_format['SP.Close']

#Loop to grab data between time intervals and store them

#def my():
#    for year in final_format:
#        if(year==1979):
#            print(year)
#        if(year!=1979):
#            pass

# %%
close = final_format[['Year', 'AU.Price', 'SP.Close']]
close.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-53-d74a568a0e02> in <module>
# ----> 1 close = final_format[['Year', 'AU.Price', 'SP.Close']]
#       2 close.head()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2932                 key = list(key)
#    2933             indexer = self.loc._convert_to_indexer(key, axis=1,
# -> 2934                                                    raise_missing=True)
#    2935
#    2936         # take() does not accept boolean indexers
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _convert_to_indexer(self, obj, axis, is_setter, raise_missing)
#    1352                 kwargs = {'raise_missing': True if is_setter else
#    1353                           raise_missing}
# -> 1354                 return self._get_listlike_indexer(obj, axis, **kwargs)[1]
#    1355         else:
#    1356             try:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1159         self._validate_read_indexer(keyarr, indexer,
#    1160                                     o._get_axis_number(axis),
# -> 1161                                     raise_missing=raise_missing)
#    1162         return keyarr, indexer
#    1163
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1250             if not(self.name == 'loc' and not raise_missing):
#    1251                 not_found = list(set(key) - set(ax))
# -> 1252                 raise KeyError("{} not in index".format(not_found))
#    1253
#    1254             # we skip the warning on Categorical/Interval
#
# KeyError: "['SP.Close'] not in index"

# %%
# Calculate the date one year from the last date in data set.
prev_year = dt.date(2012, 8, 23) - dt.timedelta(days=365)
